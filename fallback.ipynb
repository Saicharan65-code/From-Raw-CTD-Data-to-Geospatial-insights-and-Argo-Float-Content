# %%
import os
import pandas as pd
import re
import rasterio
from glob import glob
from collections import Counter, defaultdict
def make_unique(columns):
    counts = Counter()
    unique_cols = []
    for col in columns:
        counts[col] += 1
        if counts[col] > 1:
            unique_cols.append(f"{col}_{counts[col]}")
        else:
            unique_cols.append(col)
    return unique_cols
def merge_priority_columns(df, primary, secondary):
    if primary in df.columns and secondary in df.columns:
        df[primary] = df[primary].combine_first(df[secondary])
        df.drop(columns=[secondary], inplace=True)
    elif secondary in df.columns and primary not in df.columns:
        df.rename(columns={secondary: primary}, inplace=True)
    return df
def extract_base_name(col):
    col_lower = col.lower()
    if col_lower.startswith("flag"):
        return "flag"
    return col.split(':')[0].strip()
def merge_duplicate_columns_take_first(df):
    from collections import defaultdict
    grouped = defaultdict(list)
    for col in df.columns:
        base = re.sub(r'_\d+$', '', col)
        grouped[base].append(col)
    new_df = df.copy()
    for base, cols in grouped.items():
        if len(cols) > 1:
            new_df[base] = new_df[cols].bfill(axis=1).iloc[:, 0]
            new_df.drop(columns=[col for col in cols if col != base], inplace=True)
    new_df.dropna(axis=1, how='all', inplace=True)
    return new_df
def clean_lat_long_pair(lat_raw, lon_raw):
    def extract_digits_and_dir(value):
        value = (
            value.replace(',', '.')
                 .replace('v', '.')
                 .replace('"', '')
                 .replace("'", '')
                 .replace("'", '')
                 .replace("`", '')
                 .replace("°", '')  
                 .replace("º", '')    
                 .replace("˚", '')    
                 .strip()
        )
        value = re.sub(r'[^0-9NSEWnsew. ]+', '', value)
        value = re.sub(r'(?<=\d)[ .]+(?=\d)', '', value)
        value = re.sub(r'[ .]', '', value)
        match = re.match(r'^(\d+)([NSEWnsew]?)$', value)
        if not match:
            raise ValueError(f"Invalid coordinate format: {value}")
        digits, direction = match.groups()
        direction = direction.upper() if direction else None
        return digits, direction
    lat_digits, lat_dir = extract_digits_and_dir(lat_raw)
    lon_digits, lon_dir = extract_digits_and_dir(lon_raw)
    if lat_dir not in ['N', 'S']:
        lat_dir = 'N'
    if lon_dir not in ['E', 'W']:
        lon_dir = 'E'
    if lat_dir in ['E', 'W'] and lon_dir in ['E', 'W']:
        print(" Latitude has direction like longitude — correcting to N")
        lat_dir = 'N'
    elif lat_dir in ['N', 'S'] and lon_dir in ['N', 'S']:
        print(" Longitude has direction like latitude — correcting to E")
        lon_dir = 'E'
    return lat_digits + lat_dir, lon_digits + lon_dir
def parse_latitude(lat_str):
    length = len(lat_str)
    meta = lat_str[-1].upper()
    digits = lat_str[:-1]
    deg = min = sec = 0
    if length == 0 + 1:
        if lat_str[0] == '0':
            deg = int(digits[:1])
        else:
            deg = int(digits[:1])
    elif length == 1 + 1:
        if lat_str[0] == '0':
            deg = int(digits[:1])
        else:
            deg = int(digits[:1])
    elif length == 2 + 1:
        if lat_str[0] == '0':
            deg = int(digits[:2])
        else:
            deg = int(digits[:2])
    elif length == 3 + 1:
        if lat_str[0] == '0':
            deg = int(digits[:2])
            min = int(digits[2:3])
            sec = 0
        else:
            deg = int(digits[:1])
            min = int(digits[1:3])
    elif length == 4 + 1:
        if lat_str[0] == '0':
            deg = int(digits[:2])
            min = int(digits[2:4])
            sec = 0
        else:
            deg = int(digits[:1])
            min = int(digits[1:4])
    elif length == 5 + 1:
        if digits[0] in ['0', '1', '2']:
            deg = int(digits[:2])
            min = int(digits[2:4])
            sec = int(digits[4:5])
        else:
            deg = int(digits[0])
            min = int(digits[1:3])
            sec = int(digits[3:5])
    elif length == 6 + 1:
        if digits[0] in ['0', '1', '2']:
            deg = int(digits[:2])
            min = int(digits[2:4])
            sec = int(digits[4:6])
        else:
            deg = int(digits[:1])
            min = int(digits[1:3])
            sec = int(digits[3:6])
    elif length == 7 + 1:
        if digits[0] in ['0', '1', '2']:
            deg = int(digits[:2])
            min = int(digits[2:4])
            sec = int(digits[4:7])
        else:
            deg = int(digits[:2])
            min = int(digits[2:4])
            sec = int(digits[4:7])
    else:
        raise ValueError("unsupported")
    if sec > 59:
        if sec <=599:
            sec = sec/10
        else:
            sec = sec/100
    decimal = deg + (min/60) + (sec/3600)
    if meta in ['S', 'W']:
        decimal *=-1
    return round(decimal, 4)
def parse_longitude(lon_str):
    length = len(lon_str)
    meta = lon_str[-1].upper()
    digits = lon_str[:-1]
    deg = min = sec = 0
    if length == 1 + 1:
        if lon_str[0] == '0':
            deg = int(digits[:2])
        else:
            deg = int(digits[:2])
    elif length == 2 + 1:
        if lon_str[0] == '0':
            deg = int(digits[:2])
        else:
            deg = int(digits[:2]) 
    elif length == 3+ 1:
        if lon_str[0] == '0':
            deg = int(digits[:3])
        else:
            deg = int(digits[:2])
    elif length == 4 + 1:
        if lon_str[0] == '0':
            deg = int(digits[:3])
            min = int(digits[3:4])
        else:
            deg = int(digits[:2])
            min = int(digits[2:4])
    elif length == 5 + 1:
        if lon_str[0] == '0':
            deg = int(digits[:3])
            min = int(digits[3:5])
        else:
            deg = int(digits[:2])
            min = int(digits[2:4])
            sec = int(digits[4:5])
    elif length == 6 + 1:
        if lon_str[0] == '0':
            deg = int(digits[:3])
            min = int(digits[3:5])
            sec = int(digits[5:6])
        else:
            deg = int(digits[:2])
            min = int(digits[2:4])
            sec = int(digits[4:6])
    elif length == 7 + 1:
        if lon_str[0] == '0':
            deg = int(digits[:3])
            min = int(digits[3:5])
            sec = int(digits[5:7])
        else:
            deg = int(digits[:2])
            min = int(digits[2:4])
            sec = int(digits[4:7])
    elif length == 8 + 1:
        if lon_str[0] == '0':
            deg = int(digits[:3])
            min = int(digits[3:5])
            sec = int(digits[5:8])
        else:
            deg = int(digits[:2])
            min = int(digits[2:4])
            sec = int(digits[4:8])
    elif length == 9 + 1:
        if lon_str[0] == '0':
            deg = int(digits[:3])
            min = int(digits[3:6])
            sec = int(digits[6:9])
        else:
            deg = int(digits[:2])
            min = int(digits[2:5])
            sec = int(digits[5:9])
    else:
        raise ValueError("unsupported")
    if sec > 59:
        if sec <=599:
            sec = sec/10
        else:
            sec = sec/100
    decimal = deg + (min/60) + (sec/3600)
    if meta in ['S', 'W']:
        decimal *=-1
    return round(decimal, 4)
def parse_cnv(file_path, relative_path):
    print(f"Parsing {file_path}")
    metadata = {}
    parameters = []
    data_started = False
    data_lines = []
    lat_raw = None
    lon_raw = None
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            lines = f.readlines()
    except UnicodeDecodeError:
        try:
            with open(file_path, 'r', encoding='latin1') as f:
                lines = f.readlines()
        except Exception as e:
            raise RuntimeError(f"Failed to decode {file_path}: {e}")
    meta_patterns = {
        "Ship": re.compile(r"\bShip[\s.:]*\s*(.+)", re.IGNORECASE),
        "Cruise ID": re.compile(r"\bCruise\s*:\s*(.+)", re.IGNORECASE),
        "Station": re.compile(r"\bStation\s*:\s*(.+)", re.IGNORECASE),
        "Latitude": re.compile(r"\bLatitude\s*:\s*(.+)", re.IGNORECASE),
        "Longitude": re.compile(r"\bLongitude\s*:\s*(.+)", re.IGNORECASE),
    }
    for line in lines:
        line = line.strip()
        if line.startswith("*END*"):
            data_started = True
            continue
        if not data_started:
            for key, pattern in meta_patterns.items():
                match = pattern.search(line)
                if match:
                    value = match.group(1).strip()
                    if key == "Latitude":
                        lat_raw = value
                    elif key == "Longitude":
                        lon_raw = value
                    else:
                        metadata[key] = value
            if lat_raw and lon_raw and "Latitude" not in metadata:
                try:
                    lat_clean, lon_clean = clean_lat_long_pair(lat_raw, lon_raw)
                    metadata["Latitude"] = parse_latitude(lat_clean)
                    metadata["Longitude"] = parse_longitude(lon_clean)
                except Exception as e:
                    metadata["Latitude"] = "NA"
                    metadata["Longitude"] = "NA"
                    print(f"Unsupported lat/lon in {file_path}: {e}")
            if line.startswith("# start_time"):
                parts = line.split("=", 1)
                if len(parts) > 1:
                    metadata["Start Time"] = parts[1].strip()
            elif line.startswith("# name"):
                parts = line.split("=", 1)
                if len(parts) > 1:
                    parameters.append(parts[1].strip())
        elif line and not line.startswith("#"):
            data_lines.append(line)
    if not parameters:
        raise ValueError(f"No parameters found in {file_path}")
    column_names = make_unique([param.split(':')[0].strip() for param in parameters])
    clean_str = lambda s: str(s).replace(" ", "").replace(":", "-") if s is not None else "NA"
    trace_id_parts = [
        clean_str(metadata.get("Cruise ID")),
        clean_str(metadata.get("Station")),
        clean_str(metadata.get("Latitude")),
        clean_str(metadata.get("Longitude")),
        clean_str(metadata.get("Start Time")),
    ]
    trace_id = "_".join(trace_id_parts)
    metadata["TraceID"] = trace_id
    keys = ["Ship", "Cruise ID", "Station", "Latitude", "Longitude", "Start Time"]
    meta_values = [metadata.get(k, None) for k in keys]
    meta_df = pd.DataFrame([meta_values], columns=keys)
    meta_df["Parameters"] = ", ".join(column_names)
    meta_df["TraceID"] = trace_id
    meta_df["folderpath_filename"] = relative_path
    data = []
    for line in data_lines:
        try:
            values = list(map(float, line.split()))
            data.append(values)
        except ValueError:
            continue
    try:
        data_df = pd.DataFrame(data, columns=column_names[:len(data[0])] if data else column_names)
        data_df.columns = make_unique(data_df.columns)
        data_df = merge_duplicate_columns_take_first(data_df)
    except Exception as e:
        print(f" CNV data malformed or binary in {file_path} → skipping CNV")
        return meta_df, pd.DataFrame(), column_names
    if not data_df.empty and data_df.shape[1] <= 2 and len(column_names) > 5:
        print(f" CNV data malformed or binary in {file_path} → skipping CNV")
        return meta_df, pd.DataFrame(), column_names
    data_df["TraceID"] = trace_id
    data_df["folderpath_filename"] = relative_path
    return meta_df, data_df, column_names
    standard_columns = [
        'prDM', 't090C', 'sal00', 'sbeox0ML/L', 'depSM', 'svCM', 'specc', 'xmiss',  
        'bat', 'scan', 'prdM', 'tv290C', 'flECO-AFL', 'c0S/m', 'sbeox0PS', 'par', 
        'density00', 'sigma-é00', 'flag', 'oxsatML/L', 'c0mS/cm', 'potemp090C',
        'potemp068C', 'sigma-t00', 'depS', 'pr', 't068', 'OxML/L', 'nbf', 'nbin', 
        'potemp068', 'uv', 'dz/dt', 'timeS', 'gpa', 'dm', 'pta068', 'sva', 'SVC',
        'oxML/L', 'DepS', 'Pr', 'acc', 'N^2', 'N', 'E', 'E10^-8', 'svC',
        'T068', 'OxML/L', 'Xmiss', 'Sal00', 'Sigma-t00', 'Potemp068', 'Nbin', 'SvC',
        'C0S/m', 'Sbeox0ML/L', 'Sva', 'Pta068', 'sal', 'pta090C', 'avgSvC', 'potemp090', 'navg'
    ]
    keep_columns = [col for col in data_df.columns if any(
        std_col.lower() in col.lower() for std_col in standard_columns
    )]
    clean_str = lambda s: str(s).replace(" ", "").replace(":", "-") if s is not None else "NA"
    trace_id_parts = [
        clean_str(metadata.get("Cruise ID")),
        clean_str(metadata.get("Station")),
        clean_str(metadata.get("Latitude")),
        clean_str(metadata.get("Longitude")),
        clean_str(metadata.get("Start Time")),
    ]
    trace_id = "_".join(trace_id_parts)
    metadata["TraceID"] = trace_id
    data_df["TraceID"] = trace_id
    keep_columns.append("TraceID")
    if keep_columns:
        data_df = data_df[keep_columns]
    keys = ["Ship", "Cruise ID", "Station", "Latitude", "Longitude", "Start Time"]
    meta_values = [metadata.get(k, None) for k in keys]
    meta_df = pd.DataFrame([meta_values], columns=keys)
    meta_df["Parameters"] = ", ".join(column_names)
    meta_df["TraceID"] = trace_id
    meta_df["folderpath_filename"] = relative_path
    data_df["folderpath_filename"] = relative_path
    meta_cols = meta_df.columns.tolist()
    data_cols = data_df.columns.tolist()
    meta_cols.insert(meta_cols.index("TraceID") + 1, meta_cols.pop(meta_cols.index("folderpath_filename")))
    data_cols.insert(data_cols.index("TraceID") + 1, data_cols.pop(data_cols.index("folderpath_filename")))
    meta_df = meta_df[meta_cols]
    data_df = data_df[data_cols]
    return meta_df, data_df, column_names
def parse_asc(file_path, expected_columns=None):
    try:
        with open(file_path, 'r') as f:
            lines = [line.strip() for line in f.readlines() if line.strip()]
        header_line = None
        data_lines = []
        if lines and not lines[0][0].isdigit():
            header_line = lines[0]
            data_lines = lines[1:]
        else:
            data_lines = lines
        detected_from_header = False
        if expected_columns:
            sample_data_line = next((l for l in data_lines if re.match(r'^[\d\.\-]', l)), "")
            num_values = len(sample_data_line.split())

            if num_values <= len(expected_columns):
                columns = expected_columns.copy()
                used_columns = expected_columns[:num_values]
                extra_columns = expected_columns[num_values:]
            else:
                used_columns = expected_columns + [f"extra_col_{i}" for i in range(num_values - len(expected_columns))]
                extra_columns = []
                columns = used_columns
        elif header_line:
            if "  " in header_line:
                used_columns = [col.strip() for col in re.split(r' {2,}', header_line) if col.strip()]
                sample_data_line = next((l for l in data_lines if re.match(r'^[\d\.\-]', l)), "")
                num_values = len(sample_data_line.split()) if sample_data_line else 0
                
                if len(used_columns) != num_values:
                    used_columns = header_line.strip().split()

            extra_columns = []
            detected_from_header = True
        else:
            num_values = len(data_lines[0].split()) if data_lines else 0
            used_columns = [f"col_{i}" for i in range(num_values)]
            extra_columns = []
        data = []
        for line in data_lines:
            try:
                values = list(map(float, line.split()))
                row = values[:len(used_columns)]
                row += [float('nan')] * len(extra_columns)
                data.append(row)
            except ValueError:
                continue
        full_columns = used_columns + extra_columns
        df = pd.DataFrame(data, columns=full_columns)
        return df, full_columns if detected_from_header else None

    except Exception as e:
        print(f"Error reading ASC file: {file_path} → {str(e)}")
        return pd.DataFrame(), None
def preprocess_cnv_folder(folder_path):
    all_metadata = []
    all_data = []
    all_files = []

    for dirpath, dirnames, filenames in os.walk(folder_path):
        cnv_files = [os.path.join(dirpath, f) for f in filenames if f.lower().endswith(".cnv")]
        all_files.extend(cnv_files)

    print(f"Found {len(all_files)} CNV files...")

    for file_path in all_files:
        print(f"Processing: {os.path.basename(file_path)}")
        try:
            relative_path = os.path.relpath(file_path, folder_path).replace("\\", "/")
            meta_df, df, column_names = parse_cnv(file_path, relative_path) 
            all_metadata.append(meta_df)
            if df.empty:
                asc_path = os.path.splitext(file_path)[0] + ".asc"
                if os.path.exists(asc_path):
                    asc_df, asc_header = parse_asc(asc_path, expected_columns=None)
                    if not asc_df.empty:
                        if asc_header and len(asc_df.columns) == len(asc_header):
                            asc_df.columns = asc_header
                        else:
                            asc_df.columns = column_names[:asc_df.shape[1]]
                        asc_df["TraceID"] = meta_df["TraceID"].values[0]
                        asc_df["folderpath_filename"] = relative_path.replace(".cnv", ".asc")
                        all_data.append(asc_df)
                    else:
                        print(f" ASC file found but empty: {asc_path}")
                else:
                    print(f" No ASC found for: {os.path.basename(file_path)}")
            else:
                if df.shape[1] <= 2 and len(column_names) > 5:
                    print(f" CNV data malformed in {file_path}, trying ASC fallback...")
                    asc_path = os.path.splitext(file_path)[0] + ".asc"
                    if os.path.exists(asc_path):
                        asc_df, asc_header = parse_asc(asc_path, expected_columns=None)
                        if not asc_df.empty:
                            if asc_header and len(asc_df.columns) == len(asc_header):
                                asc_df.columns = asc_header
                            else:
                                asc_df.columns = column_names[:asc_df.shape[1]]
                            asc_df["TraceID"] = meta_df["TraceID"].values[0]
                            asc_df["folderpath_filename"] = relative_path.replace(".cnv", ".asc")
                            all_data.append(asc_df)
                        else:
                            print(f" ASC file found but empty: {asc_path}")
                    else:
                        print(f" No ASC found for malformed CNV: {os.path.basename(file_path)}")
                else:
                    all_data.append(df)
        except Exception as e:
            print(f"Error processing {file_path}: {e}")
    if all_data:
        merged_data = []
        for df in all_data:
            merge_pairs = [
                ('depSM', 'depS', 'DepS'),
                ('T090C', 'T090'),
                ('sal00', 'sal00_2'),
                ('sal00', 'sal', 'Sal00'),
                ('sbeox0ML/L', 'Sbeox0ML/L', 'oxML/L', 'OxML/L'),
                ('prDM', 'pr', 'Pr'),
                ('c0mS/cm', 'c0S/m', 'C0S/m'),
                ('t090C', 't068', 'T068'),
                ('t090C', 't068C'),
                ('potemp090C', 'potemp090'),
                ('potemp090C', 'pta090C'),
                ('svCM', 'svC'),
                ('potemp068', 'Potemp068', 'pta068', 'Pta068'),
                ('potemp068', 'potemp068_2'),
                ('potemp090C', 'potemp068'),
                ('xmiss', 'Xmiss'),
                ('timeS', 'TimeS'),
                ('nbin', 'Nbin'),
                ('sva', 'Sva'),
                ('avgSvC', 'SvC'),
                ('sigma-t00', 'Sigma-t00', 'sigma-t00_2'),
            ]
            for primary, *secondaries in merge_pairs:
                for secondary in secondaries:
                    df = merge_priority_columns(df, primary, secondary)
            RENAME_CASE_MAP = {
                'sal00': 'Sal00',
            }
            df.rename(columns=RENAME_CASE_MAP, inplace=True)
            merged_data.append(df)
        all_data = merged_data
    return all_metadata,all_data       
#----------ASCDAT--------
def merge_duplicate_columns_take_first(df):
    grouped = defaultdict(list)
    for col in df.columns:
        base = re.sub(r'_\d+$', '', col)
        grouped[base].append(col)
    new_df = df.copy()
    for base, cols in grouped.items():
        if len(cols) > 1:
            new_df[base] = new_df[cols].bfill(axis=1).iloc[:, 0]
            new_df.drop(columns=[col for col in cols if col != base], inplace=True)
    new_df.dropna(axis=1, how='all', inplace=True)
    return new_df

# ------------ MAIN ASC-DAT PAIR PARSER ----------------

def parse_asc_dat_pair(asc_path, dat_path, relative_path):
    print(f"Processing ASC-DAT pair: {asc_path} with {dat_path}")
    
    metadata = {
        "Ship": "NA", "Cruise ID": "NA", "Station": "NA",
        "Latitude": "NA", "Longitude": "NA", "Start Time": "NA",
        "_debug": {"file": dat_path, "lines": []}
    }

    try:
        with open(dat_path, 'r', encoding='latin1') as f:
            lines = f.readlines()
            metadata['_debug']['lines'] = lines[:10]
            for line in lines:
                line = line.strip()
                if not line:
                    continue
                def get_value(prefixes):
                    for prefix in prefixes:
                        if line.lower().startswith(prefix.lower()):
                            return line[len(prefix):].lstrip(":. ").strip()
                    return None
                if (value := get_value(['** Ship', '**Ship'])) is not None:
                    metadata['Ship'] = value or "NA"
                elif (value := get_value(['** Cruise', '**Cruise'])) is not None:
                    metadata['Cruise ID'] = value or "NA"
                elif (value := get_value(['** Station', '**Station'])) is not None:
                    # Clean cases like "No :    1357"
                    value = re.sub(r'^\s*No\s*[:]*\s*', '', value, flags=re.IGNORECASE)
                    metadata['Station'] = value or "NA"
                elif (value := get_value(['** Latitude', '**Latitude', '** Lat', '**Lat'])) is not None:
                    metadata['Latitude'] = value or "NA"
                elif (value := get_value(['** Longitude', '**Longitude', '** Long', '**Long'])) is not None:
                    metadata['Longitude'] = value or "NA"
                elif any(x in line.lower() for x in ['# start_time', 'system upload time']):
                    parts = re.split(r'[=:]', line, 1)
                    metadata['Start Time'] = parts[-1].strip() if len(parts) > 1 else "NA"
    except Exception as e:
        print(f"Error reading DAT file {dat_path}: {str(e)}")
        print(f"Debug info: {metadata['_debug']}")
        return None, None
    try:
        if metadata['Latitude'] != "NA" and metadata['Longitude'] != "NA":
            lat_clean, lon_clean = clean_lat_long_pair(metadata['Latitude'], metadata['Longitude'])
            metadata['Latitude'] = parse_latitude(lat_clean)
            metadata['Longitude'] = parse_longitude(lon_clean)
        else:
            metadata['Latitude'] = "NA"
            metadata['Longitude'] = "NA"
    except Exception as e:
        print(f" Failed to convert lat/lon for {dat_path}: {e}")
        metadata['Latitude'] = "NA"
        metadata['Longitude'] = "NA"
    try:
        with open(asc_path, 'r') as f:
            lines = [line.strip() for line in f if line.strip()]
    except Exception as e:
        print(f"Error reading ASC file: {e}")
        return None, None
    if not lines:
        print(f"Empty ASC file: {asc_path}")
        return None, None
    header_line = None
    for line in lines:
        if any(x in line for x in ['DepS', 'T068', 'Sal', 'Pr', 'Sigma', 'OxML']):
            header_line = line
            break
    if not header_line:
        print(f"No valid header found in {asc_path}")
        return None, None
    column_names = header_line.split()
    data_start = lines.index(header_line) + 1
    data = []
    for line in lines[data_start:]:
        if any(x in line for x in ['DepS', 'T068', 'Sal', 'Pr', 'Sigma', 'OxML']):
            continue
        try:
            values = list(map(float, line.split()))
            if len(values) == len(column_names):
                data.append(values)
        except ValueError:
            continue
    if not data:
        print(f"No valid data found in {asc_path}")
        return None, None
    try:
        data_df = pd.DataFrame(data, columns=make_unique(column_names))
        data_df = merge_duplicate_columns_take_first(data_df)
        trace_id = "_".join([
            str(metadata.get("Cruise ID")).replace(" ", "").replace(":", "-"),
            str(metadata.get("Station")).replace(" ", ""),
            str(metadata.get("Latitude")),
            str(metadata.get("Longitude")),
            str(metadata.get("Start Time")).replace(" ", "_")
        ])
        data_df["TraceID"] = trace_id
        data_df["folderpath_filename"] = relative_path
        column_groups = {
            "sbeox0ML/L": ["OxML/L", "ox0ML/L", "Sbeox0ML/L"],
            "oxsatML/L": ["OxsatML/L"],
            "c0mS/cm":["C0S/m"],
            "Sal00":["Sal00","Sal"],
            "potemp068C":["Potemp068", "Pta068"],
            "avgSvC":["SvC"],
            "depSM":["DepS"],
            "prDM":["Pr"],
            "potemp090C":["Potemp090"],
            "xmiss":["Xmiss"],
            "sigma-é00":["Sigma-é00"],
            "sigma-t00":["Sigma-t00"],
            "nbin":["Nbin"],
            "acc":["Acc"],
            "bat":["Bat"],
            "sva":["Sva"],
            "gpa":["Gpa"],
            "dm":["Dm"],
            "tsa":["Tsa"],
            "flag":["Flag"],
            "dz/dt":["Dz/dt"],
            "specc":["Specc"]
        }
        for unified_col, variants in column_groups.items():
            present = [col for col in data_df.columns if col in variants]
            if present:
                data_df[unified_col] = data_df[present].bfill(axis=1).iloc[:, 0]
                to_drop = [col for col in present if col != unified_col]
                data_df.drop(columns=to_drop, inplace=True)
        meta_df = pd.DataFrame([{
            "Ship": metadata["Ship"],
            "Cruise ID": metadata["Cruise ID"],
            "Station": metadata["Station"],
            "Latitude": metadata["Latitude"],
            "Longitude": metadata["Longitude"],
            "Start Time": metadata["Start Time"],
            "Parameters": ", ".join(column_names),
            "TraceID": trace_id,
            "folderpath_filename": relative_path
        }])
        return meta_df, data_df
    except Exception as e:
        print(f"Error creating DataFrames: {e}")
        return None, None
# ------------ MAIN LOOP ----------------
def map_asc_dat_files(folder_path):
    all_metadata = []
    all_data = []

    cnv_folders = set()
    for root, dirs, files in os.walk(folder_path):
        if any(f.lower().endswith('.cnv') for f in files):
            cnv_folders.add(root)
    for dirpath, dirnames, filenames in os.walk(folder_path):
        if any(cnv_folder in dirpath for cnv_folder in cnv_folders):
            print(f"Skipping {dirpath} (parent folder contains CNV files)")
            continue
        asc_files = [f for f in filenames if f.lower().endswith('.asc')]
        for asc_file in asc_files:
            base_name = os.path.splitext(asc_file)[0]
            dat_file = base_name + '.dat'
            dat_path = os.path.join(dirpath, 'datfiles', dat_file)
            if not os.path.exists(dat_path):
                dat_path = os.path.join(dirpath, dat_file)
                if not os.path.exists(dat_path):
                    parent_dir = os.path.dirname(dirpath)
                    for subfolder in ['data', 'dat']:
                        alt_path = os.path.join(parent_dir, subfolder, dat_file)
                        if os.path.exists(alt_path):
                            dat_path = alt_path
                            break
            if os.path.exists(dat_path):
                try:
                    relative_path = os.path.relpath(os.path.join(dirpath, asc_file), folder_path).replace("\\", "/")
                    meta_df, data_df = parse_asc_dat_pair(
                        os.path.join(dirpath, asc_file),
                        dat_path,
                        relative_path
                    )
                    if meta_df is not None and data_df is not None:
                        all_metadata.append(meta_df)
                        all_data.append(data_df)
                except Exception as e:
                    print(f"Error processing {asc_file} with {dat_file}: {e}")

    return all_metadata, all_data
#-------------ASCHDR--------------------------

def merge_duplicate_columns_take_first(df):
    grouped = defaultdict(list)
    for col in df.columns:
        base = re.sub(r'_\d+$', '', col)
        grouped[base].append(col)
    new_df = df.copy()
    for base, cols in grouped.items():
        if len(cols) > 1:
            new_df[base] = new_df[cols].bfill(axis=1).iloc[:, 0]
            new_df.drop(columns=[col for col in cols if col != base], inplace=True)
    new_df.dropna(axis=1, how='all', inplace=True)
    return new_df

# ------------ MAIN ASC-DAT PAIR PARSER ----------------

def parse_asc_hdr_pair(asc_path, hdr_path, relative_path):
    print(f"Processing ASC-HDR pair: {asc_path} with {hdr_path}")
    
    metadata = {
        "Ship": "NA", "Cruise ID": "NA", "Station": "NA",
        "Latitude": "NA", "Longitude": "NA", "Start Time": "NA",
        "_debug": {"file": hdr_path, "lines": []}
    }

    try:
        with open(hdr_path, 'r', encoding='latin1') as f:
            lines = f.readlines()
            metadata['_debug']['lines'] = lines[:10]
            for line in lines:
                line = line.strip()
                if not line:
                    continue
                def get_value(prefixes):
                    for prefix in prefixes:
                        if line.lower().startswith(prefix.lower()):
                            return line[len(prefix):].lstrip(":. ").strip()
                    return None
                if (value := get_value(['** Ship', '**Ship'])) is not None:
                    metadata['Ship'] = value or "NA"
                elif (value := get_value(['** Cruise', '**Cruise'])) is not None:
                    metadata['Cruise ID'] = value or "NA"
                elif (value := get_value(['** Station', '**Station'])) is not None:
                    metadata['Station'] = value or "NA"
                elif (value := get_value(['** Latitude', '**Latitude', '** Lat', '**Lat'])) is not None:
                    metadata['Latitude'] = value or "NA"
                elif (value := get_value(['** Longitude', '**Longitude', '** Long', '**Long'])) is not None:
                    metadata['Longitude'] = value or "NA"
                elif any(x in line.lower() for x in ['# start_time', 'system upload time']):
                    parts = re.split(r'[=:]', line, 1)
                    metadata['Start Time'] = parts[-1].strip() if len(parts) > 1 else "NA"
    except Exception as e:
        print(f"Error reading HDR file {hdr_path}: {str(e)}")
        print(f"Debug info: {metadata['_debug']}")
        return None, None

    try:
        if metadata['Latitude'] != "NA" and metadata['Longitude'] != "NA":
            lat_clean, lon_clean = clean_lat_long_pair(metadata['Latitude'], metadata['Longitude'])
            metadata['Latitude'] = parse_latitude(lat_clean)
            metadata['Longitude'] = parse_longitude(lon_clean)
        else:
            metadata['Latitude'] = "NA"
            metadata['Longitude'] = "NA"
    except Exception as e:
        print(f" Failed to convert lat/lon for {hdr_path}: {e}")
        metadata['Latitude'] = "NA"
        metadata['Longitude'] = "NA"

    try:
        with open(asc_path, 'r') as f:
            lines = [line.strip() for line in f if line.strip()]
    except Exception as e:
        print(f"Error reading ASC file: {e}")
        return None, None

    if not lines:
        print(f"Empty ASC file: {asc_path}")
        return None, None

    header_line = None
    for line in lines:
        if any(x in line for x in ['DepS', 'T068', 'Sal', 'Pr', 'Sigma', 'OxML']):
            header_line = line
            break

    if not header_line:
        print(f"No valid header found in {asc_path}")
        return None, None

    column_names = header_line.split()
    data_start = lines.index(header_line) + 1

    data = []
    for line in lines[data_start:]:
        if any(x in line for x in ['DepS', 'T068', 'Sal', 'Pr', 'Sigma', 'OxML']):
            continue
        try:
            values = list(map(float, line.split()))
            if len(values) == len(column_names):
                data.append(values)
        except ValueError:
            continue

    if not data:
        print(f"No valid data found in {asc_path}")
        return None, None

    try:
        data_df = pd.DataFrame(data, columns=make_unique(column_names))
        data_df = merge_duplicate_columns_take_first(data_df)
        trace_id = "_".join([
            str(metadata.get("Cruise ID")).replace(" ", "").replace(":", "-"),
            str(metadata.get("Station")).replace(" ", ""),
            str(metadata.get("Latitude")),
            str(metadata.get("Longitude")),
            str(metadata.get("Start Time")).replace(" ", "_")
        ])
        data_df["TraceID"] = trace_id
        data_df["folderpath_filename"] = relative_path
        column_groups = {
            "sbeox0ML/L": ["OxML/L", "ox0ML/L", "Sbeox0ML/L"],
            "oxsatML/L": ["OxsatML/L"],
            "c0mS/cm":["C0S/m"],
            "Sal00":["Sal00","Sal"],
            "potemp068C":["Potemp068", "Pta068"],
            "avgSvC":["SvC"],
            "depSM":["DepS"],
            "prDM":["Pr"],
            "potemp090C":["Potemp090"],
            "xmiss":["Xmiss"],
            "sigma-t00":["Sigma-t00"],
            "gpa":["Gpa"],
            "dm":["Dm"],
            "flag":["Flag"],
            "nbin":["Nbin"]
        }

        for unified_col, variants in column_groups.items():
            present = [col for col in data_df.columns if col in variants]
            if present:
                data_df[unified_col] = data_df[present].bfill(axis=1).iloc[:, 0]
                to_drop = [col for col in present if col != unified_col]
                data_df.drop(columns=to_drop, inplace=True)


        meta_df = pd.DataFrame([{
            "Ship": metadata["Ship"],
            "Cruise ID": metadata["Cruise ID"],
            "Station": metadata["Station"],
            "Latitude": metadata["Latitude"],
            "Longitude": metadata["Longitude"],
            "Start Time": metadata["Start Time"],
            "Parameters": ", ".join(column_names),
            "TraceID": trace_id,
            "folderpath_filename": relative_path
        }])

        return meta_df, data_df

    except Exception as e:
        print(f"Error creating DataFrames: {e}")
        return None, None

# ------------ MAIN LOOP ----------------
def map_asc_hdr_files(folder_path):
    all_metadata = []
    all_data = []
    skip_folders = set()
    for root, dirs, files in os.walk(folder_path):
        if any(f.lower().endswith(('.cnv', '.dat')) for f in files):
            skip_folders.add(root)
    hdr_map = {}

    for root, dirs, files in os.walk(folder_path):
        if any(skip_folder in root for skip_folder in skip_folders):
            continue

        hdr_files = [f for f in files if f.lower().endswith('.hdr')]
        asc_files = [f for f in files if f.lower().endswith('.asc')]
        dat_cnv_files = [f for f in files if f.lower().endswith(('.cnv', '.dat'))]
        if hdr_files:
            for f in hdr_files:
                base = os.path.splitext(f)[0]
                full_path = os.path.join(root, f)
                upper_base = base.upper()
                if upper_base.startswith('HDR'):
                    code = upper_base[3:]
                    hdr_map[code] = full_path
                hdr_map[upper_base] = full_path
    for root, dirs, files in os.walk(folder_path):
        if any(skip_folder in root for skip_folder in skip_folders):
            print(f"Skipping {root} (contains CNV/DAT files)")
            continue

        asc_files = [f for f in files if f.lower().endswith('.asc')]
        if not asc_files:
            continue

        for asc_file in asc_files:
            base = os.path.splitext(asc_file)[0]
            possible_codes = []
            if base.isdigit():
                possible_codes.append(base)
            if base.upper().startswith('STN'):
                possible_codes.append(base[3:])
            possible_codes.append(base)
            possible_codes.append(base.upper())

            matched = False
            for code in possible_codes:
                if code in hdr_map:
                    hdr_path = hdr_map[code]
                    try:
                        relative_path = os.path.relpath(
                            os.path.join(root, asc_file), folder_path
                        ).replace("\\", "/")

                        meta_df, data_df = parse_asc_hdr_pair(
                            os.path.join(root, asc_file),
                            hdr_path,
                            relative_path
                        )

                        if meta_df is not None and data_df is not None:
                            all_metadata.append(meta_df)
                            all_data.append(data_df)
                            print(f" Matched: {asc_file} with {os.path.basename(hdr_path)}")
                            matched = True
                            break
                    except Exception as e:
                        print(f" Error processing {asc_file} with {hdr_path}: {e}")
    return all_metadata, all_data
def main():
    folder = r"C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD"
    #ASC-CNV
    meta_asc, data_asc = preprocess_cnv_folder(folder)
    # ASC-DAT
    meta_dat, data_dat = map_asc_dat_files(folder)
    
    # ASC-HDR
    meta_hdr, data_hdr = map_asc_hdr_files(folder)

    # Concatenate all metadata and data
    all_meta = pd.concat(meta_dat + meta_hdr + meta_asc , ignore_index=True) if (meta_dat or meta_hdr or meta_asc) else pd.DataFrame()
    all_data = pd.concat(data_dat + data_hdr + data_asc, ignore_index=True) if (data_dat or data_hdr or data_asc) else pd.DataFrame()

    # Save final outputs
    if not all_meta.empty:
        all_meta.to_csv('fallback.csv', index=False, na_rep='NA')
        print(f" Saved all metadata → fallback.csv")
    if not all_data.empty:
        all_data.to_csv('fallback_data.csv', index=False, na_rep='NA')
        print(f" Saved all data → fallback_data.csv")

if __name__ == "__main__":
    main()
#--------QC----------
print("\n Running QC on extracted data...")

meta = pd.read_csv('fallback.csv')
data = pd.read_csv('fallback_data.csv')
raster = rasterio.open(r"C:\Users\aishwarya\Downloads\ETOPO1_Bed_g_geotiff\ETOPO1_Bed_g_geotiff.tif")
bathymetry = raster.read(1)

def is_at_sea(lat, lon):
    try:
        row, col = raster.index(lon, lat)
        return bathymetry[row, col] < 0
    except:
        return False
# === Profile Envelope QC Range for TEMP (GTSPP)
TEMP_PROFILE_ENVELOPE = [
    {"min_depth": 0, "max_depth": 1100, "min_value": -2.0, "max_value": 40.0},
    {"min_depth": 1100, "max_depth": 3000, "min_value": -1.5, "max_value": 18.0},
]

def get_profile_envelope(depth, envelope_table):
    for layer in envelope_table:
        if layer["min_depth"] <= depth < layer["max_depth"]:
            return layer["min_value"], layer["max_value"]
    return None, None
def profile_envelope_qc(df, depth_col='depSM', param_col='t090C', envelope_table=TEMP_PROFILE_ENVELOPE):
    flags = []
    for _, row in df.iterrows():
        depth = row.get(depth_col)
        value = row.get(param_col)

        if pd.isna(depth) or pd.isna(value):
            flags.append(9) 
            continue

        min_val, max_val = get_profile_envelope(depth, envelope_table)
        if min_val is None:
            flags.append(9)  
        elif min_val <= value <= max_val:
            flags.append(1) 
        else:
            flags.append(4)  
    return pd.Series(flags, name=f'{param_col}_PROFILE_QC')

# === QC 1: Valid datetime
meta['datetime'] = pd.to_datetime(meta['Start Time'], errors='coerce')
meta['DATE_QC'] = pd.to_datetime(meta['Start Time'], errors='coerce').dt.year.gt(1997).map({True: 1, False: 4})

# === QC 2: Valid position
valid_lat = meta['Latitude'].between(-40, 30)
valid_lon = meta['Longitude'].between(20, 160)
meta['POS_QC'] = ((valid_lat & valid_lon)).map({True: 1, False: 4})

# === QC 3: Location at Sea
print(" Checking location at sea...")
meta['SEA_QC'] = meta.apply(lambda row: 1 if is_at_sea(row['Latitude'], row['Longitude']) else 4, axis=1)

# === Combine all three station-level QC tests
meta_valid = meta[(meta['DATE_QC'] == 1) & (meta['POS_QC'] == 1) & (meta['SEA_QC'] == 1)]

# === Filter data to only valid profiles
valid_trace_ids = meta_valid['TraceID'].tolist()
#data = data[data['TraceID'].isin(valid_trace_ids)]

# === Gradient and Spike QC Functions
def gradient_test(series, threshold):
    result = (series - (series.shift(-1) + series.shift(1)) / 2).abs() <= threshold
    return result.map({True: 1, False: 4})

def spike_test(series, threshold):
    part1 = (series - (series.shift(-1) + series.shift(1)) / 2).abs()
    part2 = ((series.shift(-1) - series.shift(1)) / 2).abs()
    result = (part1 - part2) <= threshold
    return result.map({True: 1, False: 4})

# === QC 4–6: Variable-level QC for TEMP and PSAL
if 't090C' in data.columns:
    data['TEMP_QC'] = data['t090C'].between(-2, 40).map({True: 1, False: 4})
    data['TEMP_GRAD_QC'] = gradient_test(data['t090C'], 10.0)
    data['TEMP_SPIKE_QC'] = spike_test(data['t090C'], 2.0)

if 'Sal00' in data.columns:
    data['PSAL_QC'] = data['Sal00'].between(0, 41).map({True: 1, False: 4})
    data['PSAL_GRAD_QC'] = gradient_test(data['Sal00'], 5.0)
    data['PSAL_SPIKE_QC'] = spike_test(data['Sal00'], 0.3)
# === QC 7: Profile Envelope Test
if 'depSM' in data.columns and 't090C' in data.columns:
    data['TEMP_PROFILE_QC'] = profile_envelope_qc(data, depth_col='depSM', param_col='t090C')


meta.to_csv("meta.csv", index=False,na_rep='NaN')
data.to_csv("data.csv", index=False,na_rep='NaN')

print(" QC complete. Saved meta.csv and data.csv ")
# Out:
# Found 1034 CNV files...
# Processing: 1153.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1153.cnv
# Processing: 1153PP.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1153PP.CNV
# Error processing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1153PP.CNV: No parameters found in C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1153PP.CNV
# Processing: 1154a.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1154a.cnv
# Processing: 1154B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1154B.CNV
# Processing: 1154c.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1154c.cnv
# Processing: 1154mic1.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1154mic1.cnv
# Processing: 1154micr.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1154micr.cnv
# Processing: 1154papa.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1154papa.cnv
# Processing: 1154PP.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1154PP.CNV
# Processing: 1155.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1155.cnv
# Processing: 1155papa.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1155papa.cnv
# Processing: 1156.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1156.CNV
# Processing: 1156papa.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1156papa.cnv
# Processing: 1157.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1157.cnv
# Processing: 1157mic1.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1157mic1.cnv
# Processing: 1157micr.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1157micr.cnv
# Processing: 1157papa.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1157papa.cnv
# Processing: 1158a.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1158a.cnv
# Processing: 1158b.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1158b.cnv
# Processing: 1158c.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1158c.cnv
# Processing: 1158d.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1158d.cnv
# Processing: 1158mic1.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1158mic1.cnv
# Processing: 1158micr.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1158micr.cnv
# Processing: 1158pp.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1158pp.cnv
# Processing: 1159.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1159.cnv
# Processing: 1160.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1160.CNV
# Processing: 1161.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1161.cnv
# Processing: 1161a.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1161a.cnv
# Processing: 1161mic1.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1161mic1.cnv
# Processing: 1161micr.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1161micr.cnv
# Processing: 1161pp.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1161pp.cnv
# Processing: 1162.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1162.cnv
# Processing: 1162mdu.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1162mdu.cnv
# Processing: 1163.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1163.CNV
# Processing: 1163b.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1163b.cnv
# Processing: 1163c.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1163c.cnv
# Processing: 1163mic1.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1163mic1.cnv
# Processing: 1163micr.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1163micr.cnv
# Processing: 1163papa.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1163papa.cnv
# Processing: 1163pp.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1163pp.cnv
# Processing: 1164.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1164.cnv
# Processing: 1165.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1165.cnv
# Processing: 1165a.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1165a.cnv
# Processing: 1167.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1167.cnv
# Processing: 1167papa.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1167papa.cnv
# Processing: 1167pp.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1167pp.cnv
# Processing: 1168.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1168.cnv
# Processing: 1168micr.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1168micr.cnv
# Processing: 1168pp.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1168pp.cnv
# Processing: 1169.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1169.cnv
# Processing: 1170.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1170.cnv
# Processing: 1170mi2.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1170mi2.cnv
# Processing: 1170micr.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1170micr.cnv
# Processing: 1170pp.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1170pp.cnv
# Processing: 1171.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1171.CNV
# Processing: 1171pp.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1171pp.cnv
# Processing: 1172.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1172.CNV
# Processing: 1172a.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1172a.cnv
# Processing: 1173.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1173.cnv
# Processing: 1173a.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1173a.cnv
# Processing: 1174.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1174.cnv
# Processing: 1174pp.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1174pp.cnv
# Processing: 1175.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1175.cnv
# Processing: 1175j.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1175j.cnv
# Processing: 1175mdu.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1175mdu.cnv
# Processing: 1175pp.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1175pp.cnv
# Processing: 1176.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1176.cnv
# Processing: 1176mic1.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1176mic1.cnv
# Processing: 1176papa.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1176papa.cnv
# Processing: 1177.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1177.cnv
# Processing: 1178.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\1178.cnv
# Processing: CAP.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\CAP.CNV
# Error processing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\CAP.CNV: No parameters found in C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr205\CTD205\CAP.CNV
# Processing: 1179.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr206\CR206CTD\1179.CNV
# Processing: 1180.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr206\CR206CTD\1180.CNV
# Processing: 1181.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr206\CR206CTD\1181.CNV
# Processing: 1201a.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1201a.cnv
# Processing: 1201b.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1201b.cnv
# Processing: 1201c.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1201c.cnv
# Processing: 1201d.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1201d.cnv
# Processing: 1201papa.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1201papa.cnv
# Processing: 1201pp.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1201pp.cnv
# Processing: 1202.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1202.cnv
# Processing: 1202papa.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1202papa.cnv
# Processing: 1203.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1203.cnv
# Processing: 1203a.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1203a.cnv
# Processing: 1203papa.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1203papa.cnv
# Processing: 1204a.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1204a.cnv
# Processing: 1204b.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1204b.cnv
# Processing: 1204c.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1204c.cnv
# Processing: 1204d.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1204d.cnv
# Processing: 1204dpap.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1204dpap.cnv
# Processing: 1204papa.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1204papa.cnv
# Processing: 1205.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1205.cnv
# Processing: 1205a.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1205a.cnv
# Processing: 1206.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1206.cnv
# Processing: 1207.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1207.cnv
# Processing: 1208a.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1208a.cnv
# Processing: 1208b.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1208b.cnv
# Processing: 1208c.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1208c.cnv
# Processing: 1209.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1209.cnv
# Processing: 1209b.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1209b.cnv
# Processing: 1210.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1210.cnv
# Processing: 12101.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\12101.cnv
# Processing: 1211.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1211.cnv
# Processing: 1212a.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1212a.cnv
# Processing: 1212b.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1212b.cnv
# Processing: 1212c.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1212c.cnv
# Processing: 1212d.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1212d.cnv
# Processing: 1213a.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1213a.cnv
# Processing: 1213d.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1213d.cnv
# Processing: 1214a.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1214a.cnv
# Processing: 1214b.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1214b.cnv
# Processing: 1214c.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1214c.cnv
# Processing: 1214d.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr207\CR207 ctd\1214d.cnv
# Processing: OTC9.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr210\ctd\OTC9.CNV
# Processing: OTEC1.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr210\ctd\OTEC1.CNV
# Processing: 1370.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr216\CR216\1370.CNV
# Processing: 1371.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr216\CR216\1371.CNV
# Processing: 1372.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr216\CR216\1372.CNV
# Processing: 1373.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr216\CR216\1373.CNV
# Processing: 1374.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr216\CR216\1374.CNV
# Processing: 1376.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr216\CR216\1376.CNV
# Processing: 1377.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr216\CR216\1377.CNV
# Processing: 1378.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr216\CR216\1378.CNV
# Processing: 1379.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr216\CR216\1379.CNV
# Processing: 1380.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr216\CR216\1380.CNV
# Processing: 1381.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr216\CR216\1381.CNV
# Processing: 1382.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr216\CR216\1382.CNV
# Processing: 1383.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr216\CR216\1383.CNV
# Processing: 1384.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr216\CR216\1384.CNV
# Processing: 1385.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr216\CR216\1385.CNV
# Processing: 1386.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr216\CR216\1386.CNV
# Processing: 1387.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr216\CR216\1387.CNV
# Processing: 1388.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr216\CR216\1388.CNV
# Processing: 1389.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr216\CR216\1389.CNV
# Processing: 1390.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr216\CR216\1390.CNV
# Processing: 1391.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr216\CR216\1391.CNV
# Processing: CR218.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr218\CR218.CNV
# Processing: 09.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\09.CNV
# Processing: 10.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\10.CNV
# Processing: 11.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\11.CNV
# Processing: 12.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\12.CNV
# Processing: 13.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\13.CNV
# Processing: 14.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\14.CNV
# Processing: 15.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\15.CNV
# Processing: 16.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\16.CNV
# Processing: 17.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\17.CNV
# Processing: 18.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\18.CNV
# Processing: 19.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\19.CNV
# Processing: 20.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\20.CNV
# Processing: 21.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\21.CNV
# Processing: 22.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\22.CNV
# Processing: 23.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\23.CNV
# Processing: 24.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\24.CNV
# Processing: 25.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\25.CNV
#  CNV data malformed or binary in C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\25.CNV → skipping CNV
# Processing: 26.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\26.CNV
#  CNV data malformed or binary in C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\26.CNV → skipping CNV
# Processing: 27.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\27.CNV
# Processing: 28.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\28.CNV
# Processing: 29.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\29.CNV
# Processing: 30.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\30.CNV
# Processing: 31.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\31.CNV
# Processing: 32.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\32.CNV
# Processing: 33.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\33.CNV
# Processing: 34.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\34.CNV
# Processing: 35.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\35.CNV
# Processing: 36.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\36.CNV
# Processing: 37.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\37.CNV
# Processing: 38.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\38.CNV
# Processing: 39.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\39.CNV
#  CNV data malformed or binary in C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\39.CNV → skipping CNV
# Processing: 40.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\40.CNV
# Processing: 41.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\41.CNV
# Processing: 42.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\42.CNV
# Processing: 43.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\43.CNV
# Processing: 44.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\44.CNV
#  CNV data malformed or binary in C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\44.CNV → skipping CNV
# Processing: 45.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\45.CNV
# Processing: 46.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\46.CNV
# Processing: 47.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219\47.CNV
# Processing: 1476.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1476.CNV
# Error processing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1476.CNV: No parameters found in C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1476.CNV
# Processing: 1476A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1476A.CNV
# Processing: 1476B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1476B.CNV
# Processing: 1476C.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1476C.CNV
# Processing: 1476MI.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1476MI.CNV
# Processing: 1476PP.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1476PP.CNV
#  No ASC found for: 1476PP.CNV
# Processing: 1477.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1477.CNV
# Processing: 1477A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1477A.CNV
# Processing: 1478.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1478.CNV
# Processing: 1478A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1478A.CNV
# Processing: 1479.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1479.CNV
# Processing: 1479A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1479A.CNV
# Processing: 1480.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1480.CNV
# Processing: 1480S.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1480S.CNV
# Processing: 1481.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1481.CNV
# Processing: 1481B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1481B.CNV
# Processing: 1481C.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1481C.CNV
# Processing: 1481M1.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1481M1.CNV
# Processing: 1481S.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1481S.CNV
# Processing: 1482A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1482A.CNV
# Processing: 1482B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1482B.CNV
# Processing: 1482C.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1482C.CNV
# Processing: 1482MI.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1482MI.CNV
# Processing: 1483.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1483.CNV
# Processing: 1483S.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1483S.CNV
# Processing: 1484.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1484.CNV
#  CNV data malformed or binary in C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1484.CNV → skipping CNV
# Processing: 1484S.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1484S.CNV
# Processing: 1485.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1485.CNV
# Processing: 1486.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1486.CNV
# Processing: 1487.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1487.CNV
# Processing: 1487S.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1487S.CNV
# Processing: 1488A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1488A.CNV
#  No ASC found for: 1488A.CNV
# Processing: 1488AUP.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1488AUP.CNV
# Processing: 1488B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1488B.CNV
# Processing: 1488D.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1488D.CNV
#  CNV data malformed or binary in C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1488D.CNV → skipping CNV
# Processing: 1488M.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1488M.CNV
# Processing: 1488PP.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1488PP.CNV
# Processing: 1488S.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1488S.CNV
# Processing: 1489.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1489.CNV
# Processing: 1490A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1490A.CNV
# Processing: 1490B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1490B.CNV
# Processing: 1490C.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1490C.CNV
# Processing: 1490ccheck.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1490ccheck.cnv
# Processing: 1490S.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1490S.CNV
# Processing: 1491.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1491.CNV
# Processing: 1491S.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1491S.CNV
# Processing: 1492.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1492.CNV
#  CNV data malformed or binary in C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1492.CNV → skipping CNV
# Processing: 1493A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1493A.CNV
#  CNV data malformed or binary in C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1493A.CNV → skipping CNV
# Processing: 1493B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1493B.CNV
#  CNV data malformed or binary in C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1493B.CNV → skipping CNV
# Processing: 1493C.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1493C.CNV
#  CNV data malformed or binary in C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1493C.CNV → skipping CNV
# Processing: 1493MI.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1493MI.CNV
# Processing: 1493PP.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1493PP.CNV
# Processing: 1493S.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1493S.CNV
# Processing: 1494.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1494.CNV
# Processing: 1494S.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1494S.CNV
# Processing: 1495A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1495A.CNV
# Processing: 1495B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1495B.CNV
# Processing: 1495C.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1495C.CNV
# Processing: 1495MI.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1495MI.CNV
# Processing: 1495S.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1495S.CNV
# Processing: 1496.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1496.CNV
# Processing: 1496S.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1496S.CNV
# Processing: 1497.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1497.CNV
# Processing: 1497S.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1497S.CNV
# Processing: 1498.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1498.CNV
# Processing: 1499A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1499A.CNV
# Processing: 1499B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1499B.CNV
# Processing: 1499C.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1499C.CNV
# Processing: 1499M.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1499M.CNV
# Error processing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1499M.CNV: No parameters found in C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1499M.CNV
# Processing: 1499S.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1499S.CNV
# Processing: 1500A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1500A.CNV
# Processing: 1500B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1500B.CNV
# Processing: 1500C.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1500C.CNV
# Error processing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1500C.CNV: No parameters found in C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1500C.CNV
# Processing: 1500M.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1500M.CNV
# Processing: 1500PP.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1500PP.CNV
# Processing: 1501.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1501.CNV
# Processing: 1501S.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1501S.CNV
# Processing: 1502.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1502.CNV
# Processing: 1503A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1503A.CNV
# Processing: 1503B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1503B.CNV
# Processing: 1503S.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1503S.CNV
# Processing: 1504.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223\1504.CNV
# Processing: 1505.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr224\1505.CNV
# Processing: 1506A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr224\1506A.CNV
# Processing: 1506B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr224\1506B.CNV
# Processing: 1506D.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr224\1506D.CNV
# Processing: 1507.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr224\1507.CNV
# Processing: 1511.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr224\1511.CNV
# Processing: 1512T.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr224\1512T.CNV
# Processing: 1523.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr226\1523.CNV
# Processing: 1524.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr226\1524.CNV
# Processing: 1525.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr226\1525.CNV
# Processing: 1526.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr226\1526.CNV
# Processing: 1527.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr226\1527.CNV
# Processing: 1528.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr226\1528.CNV
# Processing: 1529.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr226\1529.CNV
# Processing: 1530.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr226\1530.CNV
# Processing: 1531.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr226\1531.CNV
# Processing: 1532.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr226\1532.CNV
# Processing: 1533.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr226\1533.CNV
# Processing: 1534.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr226\1534.CNV
# Processing: 1535.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr226\1535.CNV
# Processing: 1536.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr226\1536.CNV
# Processing: 1537.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr226\1537.CNV
# Processing: 1538.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr226\1538.CNV
# Processing: 1539.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr226\1539.CNV
# Processing: 1540.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr226\1540.CNV
# Processing: 1541.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr226\1541.CNV
# Processing: 1542.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr226\1542.CNV
# Processing: 21.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228\21.CNV
# Processing: 22.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228\22.CNV
# Processing: 23.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228\23.CNV
# Processing: 24.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228\24.CNV
# Processing: 25.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228\25.CNV
# Processing: 26.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228\26.CNV
# Processing: 27.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228\27.CNV
# Processing: 28.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228\28.CNV
# Processing: 29.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228\29.CNV
# Processing: 30.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228\30.CNV
# Processing: 31.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228\31.CNV
# Processing: 32.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228\32.CNV
# Processing: 33.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228\33.CNV
# Processing: 34.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228\34.CNV
# Processing: 35.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228\35.CNV
# Processing: 36.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228\36.CNV
# Processing: 37.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228\37.CNV
# Processing: 38.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228\38.CNV
# Processing: 39.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228\39.CNV
# Processing: 40.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228\40.CNV
# Processing: 41.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228\41.CNV
# Processing: 42.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228\42.CNV
# Processing: 43.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228\43.CNV
# Processing: 44.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228\44.CNV
# Processing: 45.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228\45.CNV
# Processing: 46.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228\46.CNV
# Processing: 47.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228\47.CNV
# Processing: 1606.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1606.cnv
# Processing: 1607.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1607.CNV
# Processing: 1608.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1608.CNV
# Processing: 1609.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1609.CNV
# Processing: 1610.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1610.CNV
# Processing: 1611.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1611.CNV
# Processing: 1612.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1612.CNV
# Processing: 1613.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1613.CNV
# Processing: 1613a.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1613a.cnv
# Processing: 1614.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1614.CNV
# Processing: 1615.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1615.CNV
# Processing: 1616.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1616.CNV
# Processing: 1616A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1616A.CNV
# Processing: 1617.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1617.CNV
# Processing: 1617A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1617A.CNV
# Processing: 1618.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1618.CNV
# Processing: 1619.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1619.CNV
# Processing: 1620.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1620.CNV
# Processing: 1621.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1621.CNV
# Processing: 1622.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1622.CNV
# Processing: 1622A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1622A.CNV
# Processing: 1622B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1622B.CNV
# Processing: 1622C.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1622C.CNV
# Processing: 1622D.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1622D.CNV
# Processing: 1623.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1623.CNV
# Processing: 1624.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1624.CNV
# Processing: 1625.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1625.CNV
# Processing: 1626.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1626.CNV
# Processing: 1626A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1626A.CNV
# Processing: 1627.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1627.CNV
# Processing: 1628.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1628.CNV
# Processing: 1629.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1629.CNV
# Processing: 1630.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1630.CNV
# Processing: 1631.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1631.CNV
# Processing: 1632.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1632.CNV
# Processing: 1632A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1632A.CNV
# Processing: 1633.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1633.CNV
# Processing: 1634.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1634.CNV
# Processing: 1635.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1635.CNV
# Processing: 1636.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1636.CNV
# Processing: 1637.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1637.CNV
# Processing: 1638.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1638.CNV
# Processing: 1639.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd\1639.CNV
# Processing: BEN0.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\BEN0.CNV
# Processing: BEN0A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\BEN0A.CNV
# Processing: BEN0B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\BEN0B.CNV
# Processing: BEN1.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\BEN1.CNV
# Processing: BEN10.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\BEN10.CNV
# Processing: BEN11.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\BEN11.CNV
# Processing: Ben12.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\Ben12.cnv
# Processing: Ben13.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\Ben13.cnv
# Processing: BEN14.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\BEN14.CNV
# Processing: Ben15.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\Ben15.cnv
# Processing: Ben15a.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\Ben15a.cnv
# Processing: Ben15b.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\Ben15b.cnv
# Processing: Ben16.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\Ben16.cnv
# Processing: BEN17.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\BEN17.CNV
# Processing: Ben18.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\Ben18.cnv
# Processing: Ben19.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\Ben19.cnv
# Processing: BEN2.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\BEN2.CNV
# Processing: Ben20.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\Ben20.cnv
# Processing: BEN3.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\BEN3.CNV
# Processing: BEN3A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\BEN3A.CNV
# Processing: BEN3B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\BEN3B.CNV
# Processing: BEN3C.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\BEN3C.CNV
# Processing: BEN4.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\BEN4.CNV
# Processing: Ben5.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\Ben5.cnv
# Processing: BEN6.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\BEN6.CNV
# Processing: BEN6A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\BEN6A.CNV
# Processing: BEN6B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\BEN6B.CNV
# Processing: BEN6C.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\BEN6C.CNV
# Processing: BEN7.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\BEN7.CNV
# Processing: BEN8.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\BEN8.CNV
# Processing: BEN9.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\BEN9.CNV
# Processing: BEN9A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\BEN9A.CNV
# Processing: BEN9B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\BEN9B.CNV
# Processing: BEN9C.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD\BEN9C.CNV
# Processing: 1672A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1672A.CNV
# Processing: 1672B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1672B.CNV
# Processing: 1672C.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1672C.CNV
# Processing: 1673.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1673.CNV
# Processing: 1674.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1674.CNV
# Processing: 1675.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1675.CNV
# Processing: 1676A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1676A.CNV
# Processing: 1676A_PP.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1676A_PP.CNV
# Error processing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1676A_PP.CNV: No parameters found in C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1676A_PP.CNV
# Processing: 1676B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1676B.CNV
# Processing: 1676C.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1676C.CNV
# Processing: 1676_PP.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1676_PP.CNV
# Processing: 1677.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1677.CNV
# Processing: 1678.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1678.CNV
# Processing: 1679A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1679A.CNV
# Processing: 1679_PP.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1679_PP.CNV
# Processing: 1680.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1680.CNV
# Processing: 1681.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1681.CNV
# Processing: 1682.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1682.CNV
# Processing: 1683.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1683.CNV
# Processing: 1684A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1684A.CNV
# Processing: 1684B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1684B.CNV
# Processing: 1684C.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1684C.CNV
# Processing: 1684CC.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1684CC.CNV
# Processing: 1684D.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1684D.CNV
# Processing: 1685A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1685A.CNV
# Processing: 1685A_PP.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1685A_PP.CNV
# Processing: 1685B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1685B.CNV
# Processing: 1685C.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1685C.CNV
# Processing: 1686.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1686.CNV
# Processing: 1687.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1687.CNV
# Processing: 1688.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1688.CNV
# Processing: 1689A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1689A.CNV
# Processing: 1689B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1689B.CNV
# Processing: 1689_PP.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1689_PP.CNV
# Processing: 1690A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1690A.CNV
# Processing: 1690B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1690B.CNV
# Processing: 1690C.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1690C.CNV
# Processing: 1690_PP.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1690_PP.CNV
# Processing: 1691.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1691.CNV
# Processing: 1692.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1692.CNV
# Processing: 1693.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1693.CNV
# Processing: 1694.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1694.CNV
# Processing: 1694A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1694A.CNV
# Processing: 1694B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1694B.CNV
# Processing: 1694C.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1694C.CNV
# Processing: 1695.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1695.CNV
# Processing: 1696.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1696.CNV
# Processing: 1697A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1697A.CNV
# Processing: 1697B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1697B.CNV
# Processing: 1697C.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1697C.CNV
# Processing: 1697_PP.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1697_PP.CNV
# Processing: 1698A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1698A.CNV
# Processing: 1698B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1698B.CNV
# Processing: 1698C.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1698C.CNV
# Processing: 1698_PP.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1698_PP.CNV
# Processing: 1699.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1699.CNV
# Processing: 1700.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1700.CNV
# Processing: 1701a.cnv
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1701a.cnv
# Processing: 1701B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1701B.CNV
# Processing: 1701B_PP.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1701B_PP.CNV
# Processing: 1701C.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1701C.CNV
# Processing: 1702A.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1702A.CNV
# Processing: 1702B.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1702B.CNV
# Processing: 1702C.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1702C.CNV
# Processing: 1702_PP.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1702_PP.CNV
# Processing: 1703.CNV
# Parsing C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd\1703.CNV
# Processing: 1704A.CNV
# ...
#  Matched: 1320.ASC with HDR1320.hdr
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\1321.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\HDR1321.hdr
#  Matched: 1321.ASC with HDR1321.hdr
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\1322.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\HDR1322.hdr
#  Matched: 1322.ASC with HDR1322.hdr
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\1323.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\HDR1323.hdr
#  Matched: 1323.ASC with HDR1323.hdr
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\1324.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\HDR1324.hdr
#  Matched: 1324.ASC with HDR1324.hdr
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\1325.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\HDR1325.hdr
#  Matched: 1325.ASC with HDR1325.hdr
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\STN 01.asc with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\HDR 01.HDR
#  Matched: STN 01.asc with HDR 01.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\STN 02.asc with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\HDR 02.hdr
#  Matched: STN 02.asc with HDR 02.hdr
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\STN 03.asc with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\HDR 03.HDR
#  Matched: STN 03.asc with HDR 03.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\STN 04.asc with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\HDR 04.HDR
#  Matched: STN 04.asc with HDR 04.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\STN 05.asc with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\HDR 05.HDR
#  Matched: STN 05.asc with HDR 05.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\STN 06.asc with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\HDR 06.HDR
#  Matched: STN 06.asc with HDR 06.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\STN 07.asc with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\HDR 07.HDR
#  Matched: STN 07.asc with HDR 07.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\STN 08.asc with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\HDR 08.HDR
#  Matched: STN 08.asc with HDR 08.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\STN 09.asc with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr212\ctd212\HDR 09.HDR
#  Matched: STN 09.asc with HDR 09.HDR
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr214\CTD (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr215\Cr 215_CTD\leg 1 (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr215\Cr 215_CTD\leg2 (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr216\CR216 (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr217\cr217 legI\ctd\dat (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr217\cr217leg2\ctd\dat leg2 (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr218 (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr219 (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr220\ctd (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr221\CTD DATA (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr222 (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr223 (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr224 (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr225 (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr226 (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr227\dat (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr228 (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr229 (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr230\CTD (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr231\ctd (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr232\dat (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr233\CR233_CTD (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr234\ctd\DAT (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr235\ctd (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr236\CTD (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr237\ctd-237 (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr238\ctd (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr239\CTD_CR239 (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr240\ctd_processed (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr241\CR241 CTD (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr242\cr242_ctd (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr243\CR243ctd (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr244\ctd\raw (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr245\cr245ctd1 (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr246\ctd (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr246\ctd\asc (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr246\ctd\config (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr246\ctd\dat (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr247\CR 247 Leg 1 (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr247\CR247 CTD Leg II (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr248\cr248ctd\raw (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr249\CR249 DATA\ctd Leg 2 (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr249\CR249 DATA\ctd leg1 (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr250\CR250 CTD DATA (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr251\ctd_251 (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr252\CTD CATA (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr253\ctddata (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr253\ctddata\text (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr254\CR254 CTD (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr255\ctd (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr255\ctd\asc (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cr256\CTD data\raw and con (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise166\MET (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise168\MET (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise182 (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise182\ctd (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise192 (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise192\ctd (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise192\ctd\datfiles (contains CNV/DAT files)
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise194\ctd (contains CNV/DAT files)
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1003A.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1003A.HDR
#  Matched: 1003A.ASC with 1003A.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1003B.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1003B.HDR
#  Matched: 1003B.ASC with 1003B.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1003C.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1003C.HDR
#  Matched: 1003C.ASC with 1003C.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1003D.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1003D.HDR
#  Matched: 1003D.ASC with 1003D.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1003PP.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1003PP.HDR
#  Matched: 1003PP.ASC with 1003PP.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1004.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1004.HDR
#  Matched: 1004.ASC with 1004.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1005.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1005.HDR
#  Matched: 1005.ASC with 1005.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1005PP.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1005PP.HDR
#  Matched: 1005PP.ASC with 1005PP.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1006.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1006.HDR
#  Matched: 1006.ASC with 1006.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1007.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1007.HDR
#  Matched: 1007.ASC with 1007.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1007PP.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1007PP.HDR
#  Matched: 1007PP.ASC with 1007PP.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1008.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1008.HDR
#  Matched: 1008.ASC with 1008.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1008B.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1008B.HDR
#  Matched: 1008B.ASC with 1008B.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1008C.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1008C.HDR
#  Matched: 1008C.ASC with 1008C.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1008PP.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1008PP.HDR
#  Matched: 1008PP.ASC with 1008PP.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1010.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1010.HDR
#  Matched: 1010.ASC with 1010.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1014.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1014.HDR
#  Matched: 1014.ASC with 1014.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1015.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1015.HDR
#  Matched: 1015.ASC with 1015.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1016.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1016.HDR
#  Matched: 1016.ASC with 1016.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1016PP1.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1016PP1.HDR
#  Matched: 1016PP1.ASC with 1016PP1.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1018.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1018.HDR
#  Matched: 1018.ASC with 1018.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1020.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1020.HDR
#  Matched: 1020.ASC with 1020.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1021.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1021.HDR
#  Matched: 1021.ASC with 1021.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1022.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1022.HDR
#  Matched: 1022.ASC with 1022.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1023.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1023.HDR
#  Matched: 1023.ASC with 1023.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1024.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1024.HDR
#  Matched: 1024.ASC with 1024.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1026.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1026.HDR
#  Matched: 1026.ASC with 1026.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1027.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1027.HDR
#  Matched: 1027.ASC with 1027.HDR
# Processing ASC-HDR pair: C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\1028.ASC with C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise198\location\1028.HDR
#  Matched: 1028.ASC with 1028.HDR
# Skipping C:\Users\aishwarya\OneDrive\Desktop\NEW1\CMLRE_CTD\cruise201\idas (contains CNV/DAT files)
#  Saved all metadata → fallback.csv
#  Saved all data → fallback_data.csv
#
#  Running QC on extracted data...
# 🔹 Checking location at sea...
# C:\Users\aishwarya\anaconda3\Lib\site-packages\rasterio\transform.py:410: RuntimeWarning: invalid value encountered in cast
#   new_rows = np.floor(new_rows).astype(dtype="int32")
# C:\Users\aishwarya\anaconda3\Lib\site-packages\rasterio\transform.py:411: RuntimeWarning: invalid value encountered in cast
#   new_cols = np.floor(new_cols).astype(dtype="int32")
#  QC complete. Saved meta.csv and data.csv
